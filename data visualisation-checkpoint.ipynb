# %%
import numpy as np
import pandas as pd
import seaborn as sns
# %matplotlib inline
from matplotlib import pyplot as plt

# %%
mobile = pd.read_csv('train.csv')

# %%
mobile
# Out:
#       battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  \
# 0               842     0          2.2         0   1       0           7
# 1              1021     1          0.5         1   0       1          53
# 2               563     1          0.5         1   2       1          41
# 3               615     1          2.5         0   0       0          10
# 4              1821     1          1.2         0  13       1          44
# ...             ...   ...          ...       ...  ..     ...         ...
# 1995            794     1          0.5         1   0       1           2
# 1996           1965     1          2.6         1   0       0          39
# 1997           1911     0          0.9         1   1       1          36
# 1998           1512     0          0.9         0   4       1          46
# 1999            510     1          2.0         1   5       1          45
#
#       m_dep  mobile_wt  n_cores  ...  px_height  px_width   ram  sc_h  sc_w  \
# ...

# %%
mobile.head()
# Out:
#    battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  m_dep  \
# 0            842     0          2.2         0   1       0           7    0.6
# 1           1021     1          0.5         1   0       1          53    0.7
# 2            563     1          0.5         1   2       1          41    0.9
# 3            615     1          2.5         0   0       0          10    0.8
# 4           1821     1          1.2         0  13       1          44    0.6
#
#    mobile_wt  n_cores  ...  px_height  px_width   ram  sc_h  sc_w  talk_time  \
# 0        188        2  ...         20       756  2549     9     7         19
# 1        136        3  ...        905      1988  2631    17     3          7
# 2        145        5  ...       1263      1716  2603    11     2          9
# 3        131        6  ...       1216      1786  2769    16     8         11
# 4        141        2  ...       1208      1212  1411     8     2         15
#
# ...

# %%
mobile.rename_axis('S. No',axis='rows',inplace=True)

# %%
mobile
# Out:
#        battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  \
# S. No
# 0                842     0          2.2         0   1       0           7
# 1               1021     1          0.5         1   0       1          53
# 2                563     1          0.5         1   2       1          41
# 3                615     1          2.5         0   0       0          10
# 4               1821     1          1.2         0  13       1          44
# ...              ...   ...          ...       ...  ..     ...         ...
# 1995             794     1          0.5         1   0       1           2
# 1996            1965     1          2.6         1   0       0          39
# 1997            1911     0          0.9         1   1       1          36
# 1998            1512     0          0.9         0   4       1          46
# 1999             510     1          2.0         1   5       1          45
#
# ...

# %%
plt.figure(figsize=(12,6))
plt.title("Line chart")
sns.lineplot(data=mobile[0:11])
plt.xlabel('Mobiles')
# Out:
# Text(0.5, 0, 'Mobiles')

# %%
plt.figure(figsize=(12,6))
plt.title("Line chart")
sns.lineplot(data=mobile['battery_power'][0:11])
plt.xlabel('Mobiles')
# Out:
# Text(0.5, 0, 'Mobiles')

# %%
plt.figure(figsize=(20,6))
plt.title("Line chart")
sns.barplot(data=mobile[0:11])
plt.xlabel('Mobiles')
# Out:
# Text(0.5, 0, 'Mobiles')

# %%
plt.figure(figsize=(20,6))
plt.title("Line chart")
sns.barplot(x=mobile.index[0:11],y=mobile['battery_power'][0:11])
plt.xlabel('Mobiles')
# Out:
# Text(0.5, 0, 'Mobiles')

# %%
plt.figure(figsize=(20,6))
plt.title("Heatmap")
sns.heatmap(data=mobile[0:11])
plt.xlabel('Mobiles')
# Out:
# Text(0.5, 32.09375, 'Mobiles')

# %%
plt.figure(figsize=(20,6))
plt.title("Heatmap")
sns.heatmap(data=mobile[0:11],annot=True)
plt.xlabel('Mobiles')
# Out:
# Text(0.5, 32.09375, 'Mobiles')

# %%
plt.figure(figsize=(20,6))
plt.title("Scatter Plot")
sns.scatterplot(x=mobile.index[0:100],y=mobile['battery_power'][0:100])
plt.xlabel('Mobiles')
# Out:
# Text(0.5, 0, 'Mobiles')

# %%
plt.figure(figsize=(20,6))
plt.title("Scatter Plot")
sns.regplot(x=mobile.index[0:100],y=mobile['battery_power'][0:100])
plt.xlabel('Mobiles')
# Out:
# Text(0.5, 0, 'Mobiles')

# %%
plt.figure(figsize=(20,6))
plt.title("Scatter Plot")
sns.scatterplot(x=mobile.index[0:100],y=mobile['battery_power'][0:100],hue=mobile['mobile_wt'][0:100])
plt.xlabel('Mobiles')
# Out:
# Text(0.5, 0, 'Mobiles')

# %%
plt.figure(figsize=(20,6))
plt.title("Scatter Plot")
sns.lmplot(x='clock_speed'[0:100],y='battery_power'[0:100],hue='mobile_wt'[0:100],data=mobile)
plt.xlabel('Mobiles')
# Out:
# Text(0.5, 6.79999999999999, 'Mobiles')

# %%
sns.swarmplot(x=mobile.index[0:10],y=mobile['blue'][0:10])
# Out:
# <AxesSubplot:xlabel='S. No', ylabel='blue'>

# %%
sns.swarmplot(x=mobile['blue'][0:100],y=mobile.index[0:100])
# Out:
# <AxesSubplot:xlabel='blue', ylabel='S. No'>
